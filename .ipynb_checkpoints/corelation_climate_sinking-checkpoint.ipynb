# %%
import pandas as pd

# %%
df_1 = pd.read_csv('messstellen_cleaned.csv')

# %%
df_1
# Out:
#             ms_nr bundesland behoerde                   kreis  \
# 0     bb-25500006         bb       bb               Uckermark
# 1     bb-26500002         bb       bb               Uckermark
# 2     bb-27400050         bb       bb      Ostprignitz-Ruppin
# 3     bb-27400058         bb       bb      Ostprignitz-Ruppin
# 4     bb-27400059         bb       bb      Ostprignitz-Ruppin
# ...           ...        ...      ...                     ...
# 6672    th-208486         th       th               Sonneberg
# 6673    th-208491         th       th               Sonneberg
# 6674    th-221755         th       th  Schmalkalden-Meiningen
# 6675    th-302577         th       th                    Gera
# 6676    th-303450         th       th        Altenburger Land
#
#                    bez      ags   latitude  longitude  pct_data_1990_2021  \
# 0            Landkreis  12073.0  53.422495  14.144715            0.997396
# ...

# %%
df_1.columns
# Out:
# Index(['ms_nr', 'bundesland', 'behoerde', 'kreis', 'bez', 'ags', 'latitude',
#        'longitude', 'pct_data_1990_2021', 'breakpoint_drop',
#        'trend_normalized', 'trend_bin', 'trend_raw', 'range', 'p_value'],
#       dtype='object')

# %%
df_2 = pd.read_csv('final_germany_weather_data_monthly.csv')

# %%
df_2.columns
# Out:
# Index(['time', 'tmax', 'tmin', 'prcp', 'station', 'latitude', 'longitude'], dtype='object')

# %%
df_2
# Out:
#            time  tmax  tmin  prcp          station  latitude  longitude
# 0    2018-03-01   NaN   NaN   NaN       UFS TW Ems   54.1667     6.3500
# 1    2018-08-01  19.5  17.3  87.5       UFS TW Ems   54.1667     6.3500
# 2    2018-09-01  17.1  15.6  72.5       UFS TW Ems   54.1667     6.3500
# 3    2018-10-01  14.7  12.7  53.5       UFS TW Ems   54.1667     6.3500
# 4    2018-11-01  10.4   8.2  25.5       UFS TW Ems   54.1667     6.3500
# ..          ...   ...   ...   ...              ...       ...        ...
# 526  2021-08-01  20.0  12.3  73.1  Schleswig-Jagel   54.4667     9.5167
# 527  2021-09-01  19.0  11.5  56.4  Schleswig-Jagel   54.4667     9.5167
# 528  2021-10-01  14.0   7.8  85.9  Schleswig-Jagel   54.4667     9.5167
# 529  2021-11-01   8.9   4.5  68.3  Schleswig-Jagel   54.4667     9.5167
# 530  2021-12-01   4.4   0.0  48.9  Schleswig-Jagel   54.4667     9.5167
#
# [531 rows x 7 columns]
